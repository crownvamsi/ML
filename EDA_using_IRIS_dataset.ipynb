# %% [markdown]
# <a href="https://colab.research.google.com/github/crownvamsi/ML/blob/main/EDA_using_IRIS_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
iris = datasets.load_iris()
print(iris.keys())
print(type(iris))
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])
# <class 'sklearn.utils.Bunch'>

# %%
x=iris.data
y = iris.target
_ = pd.plotting.scatter_matrix(df, c=y, s = 150, marker='D')
